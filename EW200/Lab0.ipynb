# %% [markdown]
# # My Favorite Books

# %% [markdown]
# 1. **Do Hard Things** by *Steve Magness*
# 2. **Diary of a Wimpy Kid** by *Jeff Kinney*
# 3. **Grapes of Wrath** by *John Steinbeck*

# %%
56+107
# Out:
# 163

# %%
print('Go Navy Beat Army')
# Out:
# Go Navy Beat Army

# %% [markdown]
# ![MuEditor.jpg](attachment:MuEditor.jpg)
